# %% [markdown]
# **Sentence Ranking using Lemmatization - based on Word Frequency (SRL-WF)**

# %%
import re
import string
import nltk
import heapq
import collections
from nltk.stem import WordNetLemmatizer 
from nltk import sent_tokenize
from nltk import word_tokenize
from nltk.corpus import wordnet

#Downloading all the models and corpora required
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-51089c21-c898-47f8-8956-52c10f98aa9d" name="files[]" multiple disabled />
#      <output id="result-51089c21-c898-47f8-8956-52c10f98aa9d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CricketLong.txt to CricketLong.txt

# %%
dataset = "CricketLong.txt"
def load_dataset(dataset):
  file = open(dataset,'r',encoding='cp1252')
  text = file.read()  #contains the dataset as a string
  file.close()
  return text

text = load_dataset(dataset)
print("Raw Text:")
print(text)
original_sentences = sent_tokenize(text)

#calculating the optimum length for the summary
doc_length = len(original_sentences)
summ_length = int(0.25 * doc_length)
print("Ideal Summary Length - "+ str(summ_length))
# Out:
# Raw Text:
# Cricket grew out of the many stick-and-ball games played in England 500 years ago, under a variety of different rules. The word bat is an old English word that simply means stick or club. By the seventeenth century, cricket had evolved enough to be recognisable as a distinct game and it was popular enough for its fans to be fined for playing it on Sunday instead of going to church. Till the middle of the eighteenth century, bats were roughly the same shape as hockey sticks, curving outwards at the bottom. There was a simple reason for this: the ball was bowled underarm, along the ground and the curve at the end of the bat gave the batsman the best chance of making contact. How that early version of cricket played in village England grew into the modern game played in giant stadiums in great cities is a proper subject for history because one of the uses of history is to understand how the present was made. And sport is a large part of contemporary life: it is one way in which we amuse ourselves, compete with each other, stay fit, and express our social loyalties. If tens of millions of Indians today drop everything to watch the Indian team play a Test match or a one-day international, it is reasonable for a history of India to explore how that stick-and-ball game invented in south-eastern England became the ruling passion of the Indian sub-continent. This is particularly so, since the game was linked to the wider history of colonialism and nationalism and was in part shaped by the politics of religion and caste. Our history of cricket will look first at the evolution of cricket as a game in England, and discuss the wider culture of physical training and athleticism of the time. It will then move to India, discuss the history of the adoption of cricket in this country, and trace the modern transformation of the game. In each of these sections we will see how the history of the game was connected to the social history of the time. The social and economic history of England in the eighteenth and nineteenth centuries, crickets early years, shaped the game and gave cricket its unique nature. For example, one of the peculiarities of Test cricket is that a match can go on for five days and still end in a draw. No other modern team sport takes even half as much time to complete. A football match is generally over in an hour-and-a-half of playing time. Even baseball, a long-drawn-out bat-and-ball game by the standards of modern sport, completes nine innings in less than half the time that it takes to play a limited-overs match, the shortened version of modern cricket! Another curious characteristic of cricket is that the length of the pitch is specified  22 yards  but the size or shape of the ground is not. Most other team sports, such as hockey and football lay down the dimensions of the playing area: cricket does not. Grounds can be oval like the Adelaide Oval or nearly circular, like Chepauk in Chennai. A six at the Melbourne Cricket Ground needs to clear much more ground than a lofted shot for the same reward at Feroz Shah Kotla in Delhi. Theres a historical reason behind both these oddities. Cricket was the earliest modern team sport to be codified, which is another way of saying that cricket gave itself rules and regulations so that it could be played in a uniform and standardised way well before team games like soccer and hockey. The first written Laws of Cricket were drawn up in 1744. They stated, the principals shall choose from amongst the gentlemen present two umpires who shall absolutely decide all disputes. The stumps must be 22 inches high and the bail across them six inches. The ball must be between 5 and 6 ounces, and the two sets of stumps 22 yards apart. There were no limits on the shape or size of the bat. It appears that 40 notches or runs was viewed as a very big score, probably due to the bowlers bowling quickly at shins unprotected by pads. The worlds first cricket club was formed in Hambledon in the 1760s and the ...
# Ideal Summary Length - 17

# %%
def only_ascii(word):
  for ch in word:
    if ord(ch)>127:
      return False
  return True

def initial_preprocessing(text):
  punctuation = string.punctuation
  cleaned_sentences = []

  sentences = sent_tokenize(text)
  for sentence in sentences:
    word_list = ""
    words = word_tokenize(sentence)
    for word in words:
      if(only_ascii(word)):
        if word not in punctuation:
          word_list = word_list + word.lower() + " "
    cleaned_sentences.append(word_list)   
  return cleaned_sentences 

cleaned_sentences = initial_preprocessing(text)
print(cleaned_sentences)
# Out:
# ['cricket grew out of the many stick-and-ball games played in england 500 years ago under a variety of different rules ', 'the word bat is an old english word that simply means stick or club ', 'by the seventeenth century cricket had evolved enough to be recognisable as a distinct game and it was popular enough for its fans to be fined for playing it on sunday instead of going to church ', 'till the middle of the eighteenth century bats were roughly the same shape as hockey sticks curving outwards at the bottom ', 'there was a simple reason for this the ball was bowled underarm along the ground and the curve at the end of the bat gave the batsman the best chance of making contact ', 'how that early version of cricket played in village england grew into the modern game played in giant stadiums in great cities is a proper subject for history because one of the uses of history is to understand how the present was made ', 'and sport is a large part of contemporary life it is one way in which we amuse ourselves compete with each other stay fit and express our social loyalties ', 'if tens of millions of indians today drop everything to watch the indian team play a test match or a one-day international it is reasonable for a history of india to explore how that stick-and-ball game invented in south-eastern england became the ruling passion of the indian sub-continent ', 'this is particularly so since the game was linked to the wider history of colonialism and nationalism and was in part shaped by the politics of religion and caste ', 'our history of cricket will look first at the evolution of cricket as a game in england and discuss the wider culture of physical training and athleticism of the time ', 'it will then move to india discuss the history of the adoption of cricket in this country and trace the modern transformation of the game ', 'in each of these sections we will see how the history of the game was connected to the social history of the time ', 'the social and economic history of england in the eighteenth and nineteenth centuries crickets early years shaped the game and gave cricket its unique nature ', 'for example one of the peculiarities of test cricket is that a match can go on for five days and still end in a draw ', 'no other modern team sport takes even half as much time to complete ', 'a football match is generally over in an hour-and-a-half of playing time ', 'even baseball a long-drawn-out bat-and-ball game by the standards of modern sport completes nine innings in less than half the time that it takes to play a limited-overs match the shortened version of modern cricket ', 'another curious characteristic of cricket is that the length of the pitch is specified 22 yards but the size or shape of the ground is not ', 'most other team sports such as hockey and football lay down the dimensions of the playing area cricket does not ', 'grounds can be oval like the adelaide oval or nearly circular like chepauk in chennai ', 'a six at the melbourne cricket ground needs to clear much more ground than a lofted shot for the same reward at feroz shah kotla in delhi ', 'theres a historical reason behind both these oddities ', 'cricket was the earliest modern team sport to be codified which is another way of saying that cricket gave itself rules and regulations so that it could be played in a uniform and standardised way well before team games like soccer and hockey ', 'the first written laws of cricket were drawn up in 1744 ', 'they stated the principals shall choose from amongst the gentlemen present two umpires who shall absolutely decide all disputes ', 'the stumps must be 22 inches high and the bail across them six inches ', 'the ball must be between 5 and 6 ounces and the two sets of stumps 22 yards apart ', 'there were no limits on the shape or size of the bat ', 'it appears that 40 notches or runs was viewed as a very big score probably due to the bowlers bowling quickly at shins unprotected by pads ', 'the worlds firs ...

# %%
#POS Tagging
def get_mapping(first_char):
  tag2first = dict()
  tag2first = {
              "J": wordnet.ADJ,
              "N": wordnet.NOUN,
              "V": wordnet.VERB,
              "R": wordnet.ADV
              }
  #If the first char doesn't fall under any of the above categories, it can be treated as a noun for lemmatization.
  #The word remains unaltered
  return  tag2first.get(first_char, wordnet.NOUN)  


#getting the wordnet based POS tag of the word to feed in the lemmatizer
def get_tagged_sentence(sentence):
  sent_tag = []
  pos_tag = nltk.pos_tag(sentence.split()) #Sentence is split up into words and passed to the tagger
  for i in range(0,len(sentence.split())):
    first = pos_tag[i][1][0].upper()         #first letter of the pos tag obtained
    sent_tag.append(get_mapping(first))
  return sent_tag


#Combining lemmatization with POS tagging for meaningful lemmatization with context
def sentence_lemmatization(cleaned_sentences):
  processed_sentences = []
  lr = WordNetLemmatizer()

  for sentence in cleaned_sentences:
    lemmatized_sentence = ""
    sent_tag =  get_tagged_sentence(sentence)
    i=0
    for word in sentence.split():
      root_word = lr.lemmatize(word,sent_tag[i])
      lemmatized_sentence = lemmatized_sentence + root_word.lower() + " "
      i=i+1
    processed_sentences.append(lemmatized_sentence)   
  return processed_sentences

lemmatized_text = sentence_lemmatization(cleaned_sentences)
print("---------------------------After Lemmatization------------------------")
print(lemmatized_text)
# Out:
# ---------------------------After Lemmatization------------------------
# ['cricket grow out of the many stick-and-ball game play in england 500 year ago under a variety of different rule ', 'the word bat be an old english word that simply mean stick or club ', 'by the seventeenth century cricket have evolve enough to be recognisable a a distinct game and it be popular enough for it fan to be fin for play it on sunday instead of go to church ', 'till the middle of the eighteenth century bat be roughly the same shape a hockey stick curve outwards at the bottom ', 'there be a simple reason for this the ball be bowl underarm along the ground and the curve at the end of the bat give the batsman the best chance of make contact ', 'how that early version of cricket play in village england grow into the modern game play in giant stadium in great city be a proper subject for history because one of the us of history be to understand how the present be make ', 'and sport be a large part of contemporary life it be one way in which we amuse ourselves compete with each other stay fit and express our social loyalty ', 'if ten of million of indian today drop everything to watch the indian team play a test match or a one-day international it be reasonable for a history of india to explore how that stick-and-ball game invent in south-eastern england become the rule passion of the indian sub-continent ', 'this be particularly so since the game be link to the wide history of colonialism and nationalism and be in part shape by the politics of religion and caste ', 'our history of cricket will look first at the evolution of cricket a a game in england and discuss the wide culture of physical training and athleticism of the time ', 'it will then move to india discuss the history of the adoption of cricket in this country and trace the modern transformation of the game ', 'in each of these section we will see how the history of the game be connect to the social history of the time ', 'the social and economic history of england in the eighteenth and nineteenth century cricket early year shape the game and give cricket it unique nature ', 'for example one of the peculiarity of test cricket be that a match can go on for five day and still end in a draw ', 'no other modern team sport take even half a much time to complete ', 'a football match be generally over in an hour-and-a-half of playing time ', 'even baseball a long-drawn-out bat-and-ball game by the standard of modern sport completes nine inning in less than half the time that it take to play a limited-overs match the shortened version of modern cricket ', 'another curious characteristic of cricket be that the length of the pitch be specify 22 yard but the size or shape of the ground be not ', 'most other team sport such a hockey and football lay down the dimension of the play area cricket do not ', 'ground can be oval like the adelaide oval or nearly circular like chepauk in chennai ', 'a six at the melbourne cricket ground need to clear much more ground than a lofted shot for the same reward at feroz shah kotla in delhi ', 'there a historical reason behind both these oddity ', 'cricket be the early modern team sport to be codify which be another way of say that cricket give itself rule and regulation so that it could be play in a uniform and standardised way well before team game like soccer and hockey ', 'the first write law of cricket be draw up in 1744 ', 'they state the principal shall choose from amongst the gentleman present two umpire who shall absolutely decide all dispute ', 'the stump must be 22 inch high and the bail across them six inch ', 'the ball must be between 5 and 6 ounce and the two set of stump 22 yard apart ', 'there be no limit on the shape or size of the bat ', 'it appear that 40 notch or run be view a a very big score probably due to the bowler bowl quickly at shin unprotected by pad ', 'the world first cricket club be form in hambledon in the 1760s and the marylebone cricket club mcc be found in 1787 ', 'in 1788 the mcc publish it first revi ...

# %%
#creating a weighted histogram from the sentences
word_count = {}  
wordList = []
total_stopwords = nltk.corpus.stopwords.words('english')

#obtaining word frequency
for sent in lemmatized_text: 
  for word in sent.split():
    if word not in total_stopwords:  #Stop-Word removal
        wordList.append(word)
        if word not in word_count.keys():
            word_count[word]=1
        else:
            word_count[word]+=1
            

sorted_wc = sorted(word_count.items(), key=lambda kv: kv[1], reverse=True)

#printing word frequency table
for item in sorted_wc:
    key, val = item
    if int(val)>0:
        print(key,"-",val)

#calculating word weights
word_weights={}
for key in word_count.keys():                   
    word_weights[key]=word_count[key]/max(word_count.values())           #to find relative frequency of the word
print(word_weights)
# Out:
# cricket - 33
# game - 17
# bat - 11
# play - 10
# ball - 10
# make - 10
# history - 10
# time - 9
# ground - 8
# modern - 8
# become - 8
# match - 7
# change - 7
# england - 6
# century - 6
# one - 6
# sport - 6
# first - 6
# law - 6
# rule - 5
# shape - 5
# way - 5
# team - 5
# like - 5
# boundary - 5
# industrial - 5
# go - 4
# eighteenth - 4
# hockey - 4
# give - 4
# early - 4
# village - 4
# wide - 4
# day - 4
# even - 4
# length - 4
# size - 4
# stump - 4
# common - 4
# material - 4
# year - 3
# club - 3
# bowl - 3
# batsman - 3
# present - 3
# life - 3
# social - 3
# indian - 3
# test - 3
# see - 3
# take - 3
# half - 3
# football - 3
# inning - 3
# another - 3
# specify - 3
# 22 - 3
# shot - 3
# shall - 3
# two - 3
# umpire - 3
# inch - 3
# limit - 3
# pad - 3
# also - 3
# protective - 3
# equipment - 3
# revolution - 3
# wood - 3
# grow - 2
# many - 2
# stick-and-ball - 2
# word - 2
# simply - 2
# mean - 2
# stick - 2
# enough - 2
# curve - 2
# reason - 2
# along - 2
# end - 2
# version - 2
# city - 2
# part - 2
# fit - 2
# today - 2
# india - 2
# look - 2
# discuss - 2
# country - 2
# nineteenth - 2
# draw - 2
# much - 2
# playing - 2
# characteristic - 2
# pitch - 2
# yard - 2
# lay - 2
# area - 2
# oval - 2
# six - 2
# clear - 2
# codify - 2
# regulation - 2
# write - 2
# must - 2
# bail - 2
# 5 - 2
# ounce - 2
# appear - 2
# run - 2
# bowler - 2
# 1760s - 2
# mcc - 2
# publish - 2
# revision - 2
# occur - 2
# air - 2
# result - 2
# influence - 2
# wicket - 2
# important - 2
# glove - 2
# available - 2
# remain - 2
# pre-industrial - 2
# past - 2
# rural - 2
# originally - 2
# origin - 2
# crowd - 2
# tool - 2
# piece - 2
# metal - 2
# 500 - 1
# ago - 1
# variety - 1
# different - 1
# old - 1
# english - 1
# seventeenth - 1
# evolve - 1
# recognisable - 1
# distinct - 1
# popular - 1
# fan - 1
# fin - 1
# sunday - 1
# instead - 1
# church - 1
# till - 1
# middle - 1
# roughly - 1
# outwards - 1
# bottom - 1
# simple - 1
# underarm - 1
# best - 1
# chance - 1
# contact - 1
# giant - 1
# stadium - 1
# great - 1
# proper - 1
# subject - 1
# us - 1
# understand - 1
# large - 1
# contemporary - 1
# amuse - 1
# compete - 1
# stay - 1
# express - 1
# loyalty - 1
# ten - 1
# million - 1
# drop - 1
# everything - 1
# watch - 1
# one-day - 1
# international - 1
# reasonable - 1
# explore - 1
# invent - 1
# south-eastern - 1
# passion - 1
# sub-continent - 1
# particularly - 1
# since - 1
# link - 1
# colonialism - 1
# nationalism - 1
# politics - 1
# religion - 1
# caste - 1
# evolution - 1
# culture - 1
# physical - 1
# training - 1
# athleticism - 1
# move - 1
# adoption - 1
# trace - 1
# transformation - 1
# section - 1
# connect - 1
# economic - 1
# unique - 1
# nature - 1
# example - 1
# peculiarity - 1
# five - 1
# still - 1
# complete - 1
# generally - 1
# hour-and-a-half - 1
# baseball - 1
# long-drawn-out - 1
# bat-and-ball - 1
# standard - 1
# completes - 1
# nine - 1
# less - 1
# limited-overs - 1
# shortened - 1
# curious - 1
# dimension - 1
# adelaide - 1
# nearly - 1
# circular - 1
# chepauk - 1
# chennai - 1
# melbourne - 1
# need - 1
# lofted - 1
# reward - 1
# feroz - 1
# shah - 1
# kotla - 1
# delhi - 1
# historical - 1
# behind - 1
# oddity - 1
# say - 1
# could - 1
# uniform - 1
# standardised - 1
# well - 1
# soccer - 1
# 1744 - 1
# state - 1
# principal - 1
# choose - 1
# amongst - 1
# gentleman - 1
# absolutely - 1
# decide - 1
# dispute - 1
# high - 1
# across - 1
# 6 - 1
# set - 1
# apart - 1
# 40 - 1
# notch - 1
# view - 1
# big - 1
# score - 1
# probably - 1
# due - 1
# quickly - 1
# shin - 1
# unprotected - 1
# world - 1
# form - 1
# hambledon - 1
# marylebone - 1
# found - 1
# 1787 - 1
# 1788 - 1
# guardian - 1
# mccs - 1
# bring - 1
# series - 1
# second - 1
# 1770s - 1
# rather - 1
# roll - 1
# option - 1
# deception - 1
# plus - 1
# increased - 1
# pace - 1
# open - 1
# new - 1
# possibility - 1
# spin - 1
# swing - 1
# response - 1
# master - 1
# timing - 1
# selection - 1
# immediate - 1
# replacement - 1
# curved - 1
# straight - 1
# raise - 1
# premium - 1
# skill - 1
# reduce - 1
# rough - 1
# brute - 1
# force - 1
# weight - 1
# width - 1
# four - 1
# latter - 1
# ruling - 1
# follow - 1
# 1774 - 1
# leg-before - 1
# around - 1
# third - 1
# 1780 - 1
# three - 1
# major - 1
# saw - 1
# creation - 1
# six-seam - 1
# apply - 1
# exact - 1
# circumference - 1
# introduce - 1
# previously - 1
# importantly - 1
# overarm - 1
# bowling - 1
# legal - 1
# mature - 1
# phase - 1
# late - 1
# connection - 1
# long - 1
# side - 1
# twice - 1
# rhythm - 1
# slow - 1
# factory - 1
# work - 1
# people - 1
# pay - 1
# hour - 1
# week - 1
# strictly - 1
# time-limited - 1
# routine - 1
# vagueness - 1
# unfenced - 1
# land - 1
# public - 1
# property - 1
# vary - 1
# designated - 1
# hit - 1
# fieldsman - 1
# retrieve - 1
# distance - 1
# agree - 1
# captain - 1
# yet - 1
# fundamentally - 1
# true - 1
# natural - 1
# leather - 1
# twine - 1
# cork - 1
# handmade - 1
# industrially - 1
# manufacture - 1
# slightly - 1
# cut - 1
# single - 1
# consist - 1
# blade - 1
# willow - 1
# tree - 1
# handle - 1
# cane - 1
# european - 1
# colonialist - 1
# trading - 1
# company - 1
# establish - 1
# asia - 1
# unlike - 1
# golf - 1
# tennis - 1
# refuse - 1
# remake - 1
# man-made - 1
# plastic - 1
# fibre - 1
# glass - 1
# firmly - 1
# reject - 1
# australian - 1
# cricketer - 1
# dennis - 1
# lillee - 1
# try - 1
# aluminium - 1
# outlaw - 1
# matter - 1
# technological - 1
# invention - 1
# vulcanised - 1
# rubber - 1
# lead - 1
# introduction - 1
# 1848 - 1
# soon - 1
# afterwards - 1
# would - 1
# unimaginable - 1
# without - 1
# helmet - 1
# synthetic - 1
# lightweight - 1
# {'cricket': 1.0, 'grow': 0.06060606060606061, 'many': 0.06060606060606061, 'stick-and-ball': 0.06060606060606061, 'game': 0.5151515151515151, 'play': 0.30303030303030304, 'england': 0.18181818181818182, '500': 0.030303030303030304, 'year': 0.09090909090909091, 'ago': 0.030303030303030304, 'variety': 0.030303030303030304, 'different': 0.030303030303030304, 'rule': 0.15151515151515152, 'word': 0.06060606060606061, 'bat': 0.3333333333333333, 'old': 0.030303030303030304, 'english': 0.030303030303030304, 'simply': 0.06060606060606061, 'mean': 0.06060606060606061, 'stick': 0.06060606060606061, 'club': 0.09090909090909091, 'seventeenth': 0.030303030303030304, 'century': 0.18181818181818182, 'evolve': 0.030303030303030304, 'enough': 0.06060606060606061, 'recognisable': 0.030303030303030304, 'distinct': 0.030303030303030304, 'popular': 0.030303030303030304, 'fan': 0.030303030303030304, 'fin': 0.030303030303030304, 'sunday': 0.030303030303030304, 'instead': 0.030303030303030304, 'go': 0.12121212121212122, 'church': 0.030303030303030304, 'till': 0.030303030303030304, 'middle': 0.030303030303030304, 'eighteenth': 0.12121212121212122, 'roughly': 0.030303030303030304, 'shape': 0.15151515151515152, 'hockey': 0.12121212121212122, 'curve': 0.06060606060606061, 'outwards': 0.030303030303030304, 'bottom': 0.030303030303030304, 'simple': 0.030303030303030304, 'reason': 0.06060606060606061, 'ball': 0.30303030303030304, 'bowl': 0.09090909090909091, 'underarm': 0.030303030303030304, 'along': 0.06060606060606061, 'ground': 0.24242424242424243, 'end': 0.06060606060606061, 'give': 0.12121212121212122, 'batsman': 0.09090909090909091, 'best': 0.030303030303030304, 'chance': 0.030303030303030304, 'make': 0.30303030303030304, 'contact': 0.030303030303030304, 'early': 0.12121212121212122, 'version': 0.06060606060606061, 'village': 0.12121212121212122, 'modern': 0.24242424242424243, 'giant': 0.030303030303030304, 'stadium': 0.030303030303030304, 'great': 0.030303030303030304, 'city': 0.06060606060606061, 'proper': 0.030303030303030304, 'subject': 0.030303030303030304, 'history': 0.30303030303030304, 'one': 0.18181818181818182, 'us': 0.030303030303030304, 'understand': 0.030303030303030304, 'present': 0.09090909090909091, 'sport': 0.18181818181818182, 'large': 0.030303030303030304, 'part': 0.06060606060606061, 'contemporary': 0.030303030303030304, 'life': 0.09090909090909091, 'way': 0.15151515151515152, 'amuse': 0.030303030303030304, 'compete': 0.030303030303030304, 'stay': 0.030303030303030304, 'fit': 0.06060606060606061, 'express': 0.030303030303030304, 'social': 0.09090909090909091, 'loyalty': 0.030303030303030304, 'ten': 0.030303030303030304, 'million': 0.030303030303030304, 'indian': 0.09090909090909091, 'today': 0.06060606060606061, 'drop': 0.030303030303030304, 'everything': 0.030303030303030304, 'watch': 0.030303030303030304, 'team': 0.15151515151515152, 'test': 0.09090909090909091, 'match': 0.21212121212121213, 'one-day': 0.030303030303030304, 'international': 0.030303030303030304, 'reasonable': 0.030303030303030304, 'india': 0.06060606060606061, 'explore': 0.030303030303030304, 'invent': 0.030303030303030304, 'south-eastern': 0.030303030303030304, 'become': 0.24242424242424243, 'passion': 0.030303030303030304, 'sub-continent': 0.030303030303030304, 'particularly': 0.030303030303030304, 'since': 0.030303030303030304, 'link': 0.030303030303030304, 'wide': 0.12121212121212122, 'colonialism': 0.030303030303030304, 'nationalism': 0.030303030303030304, 'politics': 0.030303030303030304, 'religion': 0.030303030303030304, 'caste': 0.030303030303030304, 'look': 0.06060606060606061, 'first': 0.18181818181818182, 'evolution': 0.030303030303030304, 'discuss': 0.06060606060606061, 'culture': 0.030303030303030304, 'physical': 0.030303030303030304, 'training': 0.030303030303030304, 'athleticism': 0.030303030303030304, 'time': 0.2727272727272727, 'move': 0.030303030303030304, 'adoption': 0.030303030303030304, 'country': 0.06060606060606061, 'trace': 0.03030303030303 ...

# %%
#The sentence score will go up if the no. of frequent words in the sentence is the more
         
sent_score = {}
sent_index = {}
count=0

for sentence in lemmatized_text:
  sent_index[sentence] = count
  for word in sentence.split():
    if word in word_weights.keys():
      if sentence not in sent_score.keys():
        sent_score[sentence]=word_weights[word]
      else:
        sent_score[sentence]+=word_weights[word]
  count = count+1
#can be improved by removing wordy sentences

print(sent_score)
# Out:
# {'cricket grow out of the many stick-and-ball game play in england 500 year ago under a variety of different rule ': 2.545454545454545, 'the word bat be an old english word that simply mean stick or club ': 0.7878787878787877, 'by the seventeenth century cricket have evolve enough to be recognisable a a distinct game and it be popular enough for it fan to be fin for play it on sunday instead of go to church ': 2.5454545454545454, 'till the middle of the eighteenth century bat be roughly the same shape a hockey stick curve outwards at the bottom ': 1.1818181818181817, 'there be a simple reason for this the ball be bowl underarm along the ground and the curve at the end of the bat give the batsman the best chance of make contact ': 1.8787878787878782, 'how that early version of cricket play in village england grow into the modern game play in giant stadium in great city be a proper subject for history because one of the us of history be to understand how the present be make ': 4.363636363636363, 'and sport be a large part of contemporary life it be one way in which we amuse ourselves compete with each other stay fit and express our social loyalty ': 1.0303030303030303, 'if ten of million of indian today drop everything to watch the indian team play a test match or a one-day international it be reasonable for a history of india to explore how that stick-and-ball game invent in south-eastern england become the rule passion of the indian sub-continent ': 2.999999999999999, 'this be particularly so since the game be link to the wide history of colonialism and nationalism and be in part shape by the politics of religion and caste ': 1.3939393939393938, 'our history of cricket will look first at the evolution of cricket a a game in england and discuss the wide culture of physical training and athleticism of the time ': 3.8484848484848477, 'it will then move to india discuss the history of the adoption of cricket in this country and trace the modern transformation of the game ': 2.3636363636363633, 'in each of these section we will see how the history of the game be connect to the social history of the time ': 1.6363636363636362, 'the social and economic history of england in the eighteenth and nineteenth century cricket early year shape the game and give cricket it unique nature ': 4.03030303030303, 'for example one of the peculiarity of test cricket be that a match can go on for five day and still end in a draw ': 1.9696969696969697, 'no other modern team sport take even half a much time to complete ': 1.2424242424242424, 'a football match be generally over in an hour-and-a-half of playing time ': 0.696969696969697, 'even baseball a long-drawn-out bat-and-ball game by the standard of modern sport completes nine inning in less than half the time that it take to play a limited-overs match the shortened version of modern cricket ': 3.6969696969696964, 'another curious characteristic of cricket be that the length of the pitch be specify 22 yard but the size or shape of the ground be not ': 2.121212121212121, 'most other team sport such a hockey and football lay down the dimension of the play area cricket do not ': 2.0, 'ground can be oval like the adelaide oval or nearly circular like chepauk in chennai ': 0.818181818181818, 'a six at the melbourne cricket ground need to clear much more ground than a lofted shot for the same reward at feroz shah kotla in delhi ': 1.9999999999999996, 'there a historical reason behind both these oddity ': 0.15151515151515152, 'cricket be the early modern team sport to be codify which be another way of say that cricket give itself rule and regulation so that it could be play in a uniform and standardised way well before team game like soccer and hockey ': 4.909090909090908, 'the first write law of cricket be draw up in 1744 ': 1.5151515151515151, 'they state the principal shall choose from amongst the gentleman present two umpire who shall absolutely decide all dispute ': 0.696969696969697, 'the stump must  ...

# %%
best_sentences = heapq.nlargest(summ_length,sent_score,key=sent_score.get)
summary_indices=[]
summary=''

for sentence in best_sentences:
  summary_indices.append(sent_index[sentence])
summary_indices.sort() #to maintain coherency

for index in range(0,len(original_sentences)):
  if index in summary_indices:
    summary = summary + original_sentences[index] +'\n'
    
print("***SUMMARY***\n\n"+summary)
# Out:
# ***SUMMARY***
#
# Cricket grew out of the many stick-and-ball games played in England 500 years ago, under a variety of different rules.
# By the seventeenth century, cricket had evolved enough to be recognisable as a distinct game and it was popular enough for its fans to be fined for playing it on Sunday instead of going to church.
# How that early version of cricket played in village England grew into the modern game played in giant stadiums in great cities is a proper subject for history because one of the uses of history is to understand how the present was made.
# If tens of millions of Indians today drop everything to watch the Indian team play a Test match or a one-day international, it is reasonable for a history of India to explore how that stick-and-ball game invented in south-eastern England became the ruling passion of the Indian sub-continent.
# Our history of cricket will look first at the evolution of cricket as a game in England, and discuss the wider culture of physical training and athleticism of the time.
# It will then move to India, discuss the history of the adoption of cricket in this country, and trace the modern transformation of the game.
# The social and economic history of England in the eighteenth and nineteenth centuries, crickets early years, shaped the game and gave cricket its unique nature.
# Even baseball, a long-drawn-out bat-and-ball game by the standards of modern sport, completes nine innings in less than half the time that it takes to play a limited-overs match, the shortened version of modern cricket!
# Another curious characteristic of cricket is that the length of the pitch is specified  22 yards  but the size or shape of the ground is not.
# Cricket was the earliest modern team sport to be codified, which is another way of saying that cricket gave itself rules and regulations so that it could be played in a uniform and standardised way well before team games like soccer and hockey.
# The worlds first cricket club was formed in Hambledon in the 1760s and the Marylebone Cricket Club (MCC) was founded in 1787.
# By 1780, three days had become the length of a major match, and this year also saw the creation of the first six-seam cricket ball.
# While many important changes occurred during the nineteenth century (the rule about wide balls was applied, the exact circumference of the ball was specified, protective equipment like pads and gloves became available, boundaries were introduced where previously all shots had to be run and, most importantly, overarm bowling became legal) cricket remained a pre-industrial sport that matured during the early phase of the Industrial Revolution, the late eighteenth century.
# This history has made cricket a game with characteristics of both the past and the present day.
# Modern factory work meant that people were paid by the hour or the day or the week: games that were codified after the industrial revolution, like football and hockey, were strictly time-limited to fit the routines of industrial city life.
# In the same way, crickets vagueness about the size of a cricket ground is a result of its village origins.
# If you look at the games equipment, you can see how cricket both changed with changing times and yet fundamentally remained true to its origins in rural England.

# %%
#writing the summary into a text file
from google.colab import files

filename = "SRL_WF_Summary.txt"

with open(filename,"w") as f:
  f.write(summary)

files.download(filename)
