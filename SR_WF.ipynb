# %% [markdown]
# **Sentence Ranking based on Word Frequency (SR-WF)**

# %%
import re
import string
import nltk
import heapq
import collections
from nltk.stem import WordNetLemmatizer 
from nltk import sent_tokenize
from nltk import word_tokenize
from nltk.corpus import wordnet

#Downloading all the models and corpora required
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-50c38ff5-3285-40ee-bfd0-fe8f2bf2d135" name="files[]" multiple disabled />
#      <output id="result-50c38ff5-3285-40ee-bfd0-fe8f2bf2d135">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CricketLong.txt to CricketLong (1).txt

# %%
dataset = "CricketLong.txt"
def load_dataset(dataset):
  file = open(dataset,'r',encoding='cp1252')
  text = file.read()  #contains the dataset as a string
  file.close()
  return text

text = load_dataset(dataset)
print("Raw Text:")
print(text)
original_sentences = sent_tokenize(text)

#calculating the optimum length for the summary
doc_length = len(original_sentences)
summ_length = int(0.25 * doc_length)
print("Ideal Summary Length - "+ str(summ_length))
# Out:
# Raw Text:
# Cricket grew out of the many stick-and-ball games played in England 500 years ago, under a variety of different rules. The word bat is an old English word that simply means stick or club. By the seventeenth century, cricket had evolved enough to be recognisable as a distinct game and it was popular enough for its fans to be fined for playing it on Sunday instead of going to church. Till the middle of the eighteenth century, bats were roughly the same shape as hockey sticks, curving outwards at the bottom. There was a simple reason for this: the ball was bowled underarm, along the ground and the curve at the end of the bat gave the batsman the best chance of making contact. How that early version of cricket played in village England grew into the modern game played in giant stadiums in great cities is a proper subject for history because one of the uses of history is to understand how the present was made. And sport is a large part of contemporary life: it is one way in which we amuse ourselves, compete with each other, stay fit, and express our social loyalties. If tens of millions of Indians today drop everything to watch the Indian team play a Test match or a one-day international, it is reasonable for a history of India to explore how that stick-and-ball game invented in south-eastern England became the ruling passion of the Indian sub-continent. This is particularly so, since the game was linked to the wider history of colonialism and nationalism and was in part shaped by the politics of religion and caste. Our history of cricket will look first at the evolution of cricket as a game in England, and discuss the wider culture of physical training and athleticism of the time. It will then move to India, discuss the history of the adoption of cricket in this country, and trace the modern transformation of the game. In each of these sections we will see how the history of the game was connected to the social history of the time. The social and economic history of England in the eighteenth and nineteenth centuries, crickets early years, shaped the game and gave cricket its unique nature. For example, one of the peculiarities of Test cricket is that a match can go on for five days and still end in a draw. No other modern team sport takes even half as much time to complete. A football match is generally over in an hour-and-a-half of playing time. Even baseball, a long-drawn-out bat-and-ball game by the standards of modern sport, completes nine innings in less than half the time that it takes to play a limited-overs match, the shortened version of modern cricket! Another curious characteristic of cricket is that the length of the pitch is specified  22 yards  but the size or shape of the ground is not. Most other team sports, such as hockey and football lay down the dimensions of the playing area: cricket does not. Grounds can be oval like the Adelaide Oval or nearly circular, like Chepauk in Chennai. A six at the Melbourne Cricket Ground needs to clear much more ground than a lofted shot for the same reward at Feroz Shah Kotla in Delhi. Theres a historical reason behind both these oddities. Cricket was the earliest modern team sport to be codified, which is another way of saying that cricket gave itself rules and regulations so that it could be played in a uniform and standardised way well before team games like soccer and hockey. The first written Laws of Cricket were drawn up in 1744. They stated, the principals shall choose from amongst the gentlemen present two umpires who shall absolutely decide all disputes. The stumps must be 22 inches high and the bail across them six inches. The ball must be between 5 and 6 ounces, and the two sets of stumps 22 yards apart. There were no limits on the shape or size of the bat. It appears that 40 notches or runs was viewed as a very big score, probably due to the bowlers bowling quickly at shins unprotected by pads. The worlds first cricket club was formed in Hambledon in the 1760s and the ...
# Ideal Summary Length - 17

# %%
def only_ascii(word):
  for ch in word:
    if ord(ch)>127:
      return False
  return True

def initial_preprocessing(text):
  punctuation = string.punctuation
  cleaned_sentences = []

  sentences = sent_tokenize(text)
  for sentence in sentences:
    word_list = ""
    words = word_tokenize(sentence)
    for word in words:
      if(only_ascii(word)):
        if word not in punctuation:
          word_list = word_list + word.lower() + " "
    cleaned_sentences.append(word_list)   
  return cleaned_sentences 

cleaned_sentences = initial_preprocessing(text)
print(cleaned_sentences)
# Out:
# ['cricket grew out of the many stick-and-ball games played in england 500 years ago under a variety of different rules ', 'the word bat is an old english word that simply means stick or club ', 'by the seventeenth century cricket had evolved enough to be recognisable as a distinct game and it was popular enough for its fans to be fined for playing it on sunday instead of going to church ', 'till the middle of the eighteenth century bats were roughly the same shape as hockey sticks curving outwards at the bottom ', 'there was a simple reason for this the ball was bowled underarm along the ground and the curve at the end of the bat gave the batsman the best chance of making contact ', 'how that early version of cricket played in village england grew into the modern game played in giant stadiums in great cities is a proper subject for history because one of the uses of history is to understand how the present was made ', 'and sport is a large part of contemporary life it is one way in which we amuse ourselves compete with each other stay fit and express our social loyalties ', 'if tens of millions of indians today drop everything to watch the indian team play a test match or a one-day international it is reasonable for a history of india to explore how that stick-and-ball game invented in south-eastern england became the ruling passion of the indian sub-continent ', 'this is particularly so since the game was linked to the wider history of colonialism and nationalism and was in part shaped by the politics of religion and caste ', 'our history of cricket will look first at the evolution of cricket as a game in england and discuss the wider culture of physical training and athleticism of the time ', 'it will then move to india discuss the history of the adoption of cricket in this country and trace the modern transformation of the game ', 'in each of these sections we will see how the history of the game was connected to the social history of the time ', 'the social and economic history of england in the eighteenth and nineteenth centuries crickets early years shaped the game and gave cricket its unique nature ', 'for example one of the peculiarities of test cricket is that a match can go on for five days and still end in a draw ', 'no other modern team sport takes even half as much time to complete ', 'a football match is generally over in an hour-and-a-half of playing time ', 'even baseball a long-drawn-out bat-and-ball game by the standards of modern sport completes nine innings in less than half the time that it takes to play a limited-overs match the shortened version of modern cricket ', 'another curious characteristic of cricket is that the length of the pitch is specified 22 yards but the size or shape of the ground is not ', 'most other team sports such as hockey and football lay down the dimensions of the playing area cricket does not ', 'grounds can be oval like the adelaide oval or nearly circular like chepauk in chennai ', 'a six at the melbourne cricket ground needs to clear much more ground than a lofted shot for the same reward at feroz shah kotla in delhi ', 'theres a historical reason behind both these oddities ', 'cricket was the earliest modern team sport to be codified which is another way of saying that cricket gave itself rules and regulations so that it could be played in a uniform and standardised way well before team games like soccer and hockey ', 'the first written laws of cricket were drawn up in 1744 ', 'they stated the principals shall choose from amongst the gentlemen present two umpires who shall absolutely decide all disputes ', 'the stumps must be 22 inches high and the bail across them six inches ', 'the ball must be between 5 and 6 ounces and the two sets of stumps 22 yards apart ', 'there were no limits on the shape or size of the bat ', 'it appears that 40 notches or runs was viewed as a very big score probably due to the bowlers bowling quickly at shins unprotected by pads ', 'the worlds firs ...

# %%
#creating a weighted histogram from the sentences
word_count = {}  
wordList = []
total_stopwords = nltk.corpus.stopwords.words('english')

#obtaining word frequency
for sent in cleaned_sentences: 
  for word in sent.split():
    if word not in total_stopwords:  #Stop-Word removal
        wordList.append(word)
        if word not in word_count.keys():
            word_count[word]=1
        else:
            word_count[word]+=1
            

sorted_wc = sorted(word_count.items(), key=lambda kv: kv[1], reverse=True)

#printing word frequency table
for item in sorted_wc:
    key, val = item
    if int(val)>0:
        print(key,"-",val)

#calculating word weights
word_weights={}
for key in word_count.keys():                   
    word_weights[key]=word_count[key]/max(word_count.values())           #to find relative frequency of the word
print(word_weights)
# Out:
# cricket - 27
# game - 13
# bat - 10
# history - 10
# ball - 9
# made - 9
# modern - 8
# time - 8
# ground - 7
# became - 7
# england - 6
# one - 6
# match - 6
# first - 6
# crickets - 6
# played - 5
# century - 5
# sport - 5
# way - 5
# team - 5
# like - 5
# laws - 5
# industrial - 5
# games - 4
# playing - 4
# eighteenth - 4
# hockey - 4
# gave - 4
# village - 4
# even - 4
# length - 4
# size - 4
# boundaries - 4
# rules - 3
# club - 3
# shape - 3
# early - 3
# present - 3
# life - 3
# social - 3
# play - 3
# test - 3
# half - 3
# football - 3
# innings - 3
# another - 3
# specified - 3
# 22 - 3
# shall - 3
# two - 3
# stumps - 3
# inches - 3
# pads - 3
# also - 3
# protective - 3
# equipment - 3
# revolution - 3
# materials - 3
# wood - 3
# grew - 2
# many - 2
# stick-and-ball - 2
# years - 2
# word - 2
# simply - 2
# enough - 2
# reason - 2
# along - 2
# end - 2
# batsman - 2
# version - 2
# part - 2
# fit - 2
# today - 2
# indian - 2
# india - 2
# ruling - 2
# wider - 2
# shaped - 2
# look - 2
# discuss - 2
# country - 2
# see - 2
# nineteenth - 2
# days - 2
# takes - 2
# much - 2
# pitch - 2
# yards - 2
# lay - 2
# area - 2
# oval - 2
# six - 2
# shot - 2
# codified - 2
# regulations - 2
# written - 2
# umpires - 2
# must - 2
# 5 - 2
# ounces - 2
# bowlers - 2
# bowling - 2
# 1760s - 2
# mcc - 2
# published - 2
# revision - 2
# changes - 2
# occurred - 2
# common - 2
# air - 2
# change - 2
# result - 2
# wide - 2
# wicket - 2
# important - 2
# gloves - 2
# available - 2
# remained - 2
# pre-industrial - 2
# past - 2
# day - 2
# rural - 2
# originally - 2
# went - 2
# origins - 2
# commons - 2
# crowd - 2
# changed - 2
# tools - 2
# metal - 2
# 500 - 1
# ago - 1
# variety - 1
# different - 1
# old - 1
# english - 1
# means - 1
# stick - 1
# seventeenth - 1
# evolved - 1
# recognisable - 1
# distinct - 1
# popular - 1
# fans - 1
# fined - 1
# sunday - 1
# instead - 1
# going - 1
# church - 1
# till - 1
# middle - 1
# bats - 1
# roughly - 1
# sticks - 1
# curving - 1
# outwards - 1
# bottom - 1
# simple - 1
# bowled - 1
# underarm - 1
# curve - 1
# best - 1
# chance - 1
# making - 1
# contact - 1
# giant - 1
# stadiums - 1
# great - 1
# cities - 1
# proper - 1
# subject - 1
# uses - 1
# understand - 1
# large - 1
# contemporary - 1
# amuse - 1
# compete - 1
# stay - 1
# express - 1
# loyalties - 1
# tens - 1
# millions - 1
# indians - 1
# drop - 1
# everything - 1
# watch - 1
# one-day - 1
# international - 1
# reasonable - 1
# explore - 1
# invented - 1
# south-eastern - 1
# passion - 1
# sub-continent - 1
# particularly - 1
# since - 1
# linked - 1
# colonialism - 1
# nationalism - 1
# politics - 1
# religion - 1
# caste - 1
# evolution - 1
# culture - 1
# physical - 1
# training - 1
# athleticism - 1
# move - 1
# adoption - 1
# trace - 1
# transformation - 1
# sections - 1
# connected - 1
# economic - 1
# centuries - 1
# unique - 1
# nature - 1
# example - 1
# peculiarities - 1
# go - 1
# five - 1
# still - 1
# draw - 1
# complete - 1
# generally - 1
# hour-and-a-half - 1
# baseball - 1
# long-drawn-out - 1
# bat-and-ball - 1
# standards - 1
# completes - 1
# nine - 1
# less - 1
# limited-overs - 1
# shortened - 1
# curious - 1
# characteristic - 1
# sports - 1
# dimensions - 1
# grounds - 1
# adelaide - 1
# nearly - 1
# circular - 1
# chepauk - 1
# chennai - 1
# melbourne - 1
# needs - 1
# clear - 1
# lofted - 1
# reward - 1
# feroz - 1
# shah - 1
# kotla - 1
# delhi - 1
# theres - 1
# historical - 1
# behind - 1
# oddities - 1
# earliest - 1
# saying - 1
# could - 1
# uniform - 1
# standardised - 1
# well - 1
# soccer - 1
# drawn - 1
# 1744 - 1
# stated - 1
# principals - 1
# choose - 1
# amongst - 1
# gentlemen - 1
# absolutely - 1
# decide - 1
# disputes - 1
# high - 1
# bail - 1
# across - 1
# 6 - 1
# sets - 1
# apart - 1
# limits - 1
# appears - 1
# 40 - 1
# notches - 1
# runs - 1
# viewed - 1
# big - 1
# score - 1
# probably - 1
# due - 1
# quickly - 1
# shins - 1
# unprotected - 1
# worlds - 1
# formed - 1
# hambledon - 1
# marylebone - 1
# founded - 1
# 1787 - 1
# 1788 - 1
# guardian - 1
# mccs - 1
# brought - 1
# series - 1
# second - 1
# 1770s - 1
# rather - 1
# roll - 1
# options - 1
# deception - 1
# plus - 1
# increased - 1
# pace - 1
# opened - 1
# new - 1
# possibilities - 1
# spin - 1
# swing - 1
# response - 1
# batsmen - 1
# master - 1
# timing - 1
# selection - 1
# immediate - 1
# replacement - 1
# curved - 1
# straight - 1
# raised - 1
# premium - 1
# skill - 1
# reduced - 1
# influence - 1
# rough - 1
# brute - 1
# force - 1
# weight - 1
# limited - 1
# width - 1
# four - 1
# latter - 1
# followed - 1
# appeared - 1
# 1774 - 1
# leg-before - 1
# law - 1
# around - 1
# third - 1
# stump - 1
# 1780 - 1
# three - 1
# become - 1
# major - 1
# year - 1
# saw - 1
# creation - 1
# six-seam - 1
# rule - 1
# balls - 1
# applied - 1
# exact - 1
# circumference - 1
# introduced - 1
# previously - 1
# shots - 1
# run - 1
# importantly - 1
# overarm - 1
# legal - 1
# matured - 1
# phase - 1
# late - 1
# characteristics - 1
# connection - 1
# seen - 1
# matches - 1
# limit - 1
# long - 1
# took - 1
# bowl - 1
# side - 1
# twice - 1
# rhythms - 1
# slower - 1
# factory - 1
# work - 1
# meant - 1
# people - 1
# paid - 1
# hour - 1
# week - 1
# strictly - 1
# time-limited - 1
# routines - 1
# city - 1
# vagueness - 1
# unfenced - 1
# land - 1
# public - 1
# property - 1
# varied - 1
# designated - 1
# boundary - 1
# hits - 1
# cleared - 1
# fieldsman - 1
# retrieve - 1
# distance - 1
# umpire - 1
# agree - 1
# captains - 1
# changing - 1
# times - 1
# yet - 1
# fundamentally - 1
# true - 1
# natural - 1
# bails - 1
# leather - 1
# twine - 1
# cork - 1
# handmade - 1
# industrially - 1
# manufactured - 1
# material - 1
# slightly - 1
# cut - 1
# single - 1
# piece - 1
# consists - 1
# pieces - 1
# blade - 1
# willow - 1
# tree - 1
# handle - 1
# cane - 1
# european - 1
# colonialists - 1
# trading - 1
# companies - 1
# established - 1
# asia - 1
# unlike - 1
# golf - 1
# tennis - 1
# refused - 1
# remake - 1
# man-made - 1
# plastic - 1
# fibre - 1
# glass - 1
# firmly - 1
# rejected - 1
# australian - 1
# cricketer - 1
# dennis - 1
# lillee - 1
# tried - 1
# aluminium - 1
# outlawed - 1
# matter - 1
# influenced - 1
# technological - 1
# invention - 1
# vulcanised - 1
# rubber - 1
# led - 1
# introduction - 1
# 1848 - 1
# soon - 1
# afterwards - 1
# would - 1
# unimaginable - 1
# without - 1
# helmets - 1
# synthetic - 1
# lightweight - 1
# {'cricket': 1.0, 'grew': 0.07407407407407407, 'many': 0.07407407407407407, 'stick-and-ball': 0.07407407407407407, 'games': 0.14814814814814814, 'played': 0.18518518518518517, 'england': 0.2222222222222222, '500': 0.037037037037037035, 'years': 0.07407407407407407, 'ago': 0.037037037037037035, 'variety': 0.037037037037037035, 'different': 0.037037037037037035, 'rules': 0.1111111111111111, 'word': 0.07407407407407407, 'bat': 0.37037037037037035, 'old': 0.037037037037037035, 'english': 0.037037037037037035, 'simply': 0.07407407407407407, 'means': 0.037037037037037035, 'stick': 0.037037037037037035, 'club': 0.1111111111111111, 'seventeenth': 0.037037037037037035, 'century': 0.18518518518518517, 'evolved': 0.037037037037037035, 'enough': 0.07407407407407407, 'recognisable': 0.037037037037037035, 'distinct': 0.037037037037037035, 'game': 0.48148148148148145, 'popular': 0.037037037037037035, 'fans': 0.037037037037037035, 'fined': 0.037037037037037035, 'playing': 0.14814814814814814, 'sunday': 0.037037037037037035, 'instead': 0.037037037037037035, 'going': 0.037037037037037035, 'church': 0.037037037037037035, 'till': 0.037037037037037035, 'middle': 0.037037037037037035, 'eighteenth': 0.14814814814814814, 'bats': 0.037037037037037035, 'roughly': 0.037037037037037035, 'shape': 0.1111111111111111, 'hockey': 0.14814814814814814, 'sticks': 0.037037037037037035, 'curving': 0.037037037037037035, 'outwards': 0.037037037037037035, 'bottom': 0.037037037037037035, 'simple': 0.037037037037037035, 'reason': 0.07407407407407407, 'ball': 0.3333333333333333, 'bowled': 0.037037037037037035, 'underarm': 0.037037037037037035, 'along': 0.07407407407407407, 'ground': 0.25925925925925924, 'curve': 0.037037037037037035, 'end': 0.07407407407407407, 'gave': 0.14814814814814814, 'batsman': 0.07407407407407407, 'best': 0.037037037037037035, 'chance': 0.037037037037037035, 'making': 0.037037037037037035, 'contact': 0.037037037037037035, 'early': 0.1111111111111111, 'version': 0.07407407407407407, 'village': 0.14814814814814814, 'modern': 0.2962962962962963, 'giant': 0.037037037037037035, 'stadiums': 0.037037037037037035, 'great': 0.037037037037037035, 'cities': 0.037037037037037035, 'proper': 0.037037037037037035, 'subject': 0.037037037037037035, 'history': 0.37037037037037035, 'one': 0.2222222222222222, 'uses': 0.037037037037037035, 'understand': 0.037037037037037035, 'present': 0.1111111111111111, 'made': 0.3333333333333333, 'sport': 0.18518518518518517, 'large': 0.037037037037037035, 'part': 0.07407407407407407, 'contemporary': 0.037037037037037035, 'life': 0.1111111111111111, 'way': 0.18518518518518517, 'amuse': 0.037037037037037035, 'compete': 0.037037037037037035, 'stay': 0.037037037037037035, 'fit': 0.07407407407407407, 'express': 0.037037037037037035, 'social': 0.1111111111111111, 'loyalties': 0.037037037037037035, 'tens': 0.037037037037037035, 'millions': 0.037037037037037035, 'indians': 0.037037037037037035, 'today': 0.07407407407407407, 'drop': 0.037037037037037035, 'everything': 0.037037037037037035, 'watch': 0.037037037037037035, 'indian': 0.07407407407407407, 'team': 0.18518518518518517, 'play': 0.1111111111111111, 'test': 0.1111111111111111, 'match': 0.2222222222222222, 'one-day': 0.037037037037037035, 'international': 0.037037037037037035, 'reasonable': 0.037037037037037035, 'india': 0.07407407407407407, 'explore': 0.037037037037037035, 'invented': 0.037037037037037035, 'south-eastern': 0.037037037037037035, 'became': 0.25925925925925924, 'ruling': 0.07407407407407407, 'passion': 0.037037037037037035, 'sub-continent': 0.037037037037037035, 'particularly': 0.037037037037037035, 'since': 0.037037037037037035, 'linked': 0.037037037037037035, 'wider': 0.07407407407407407, 'colonialism': 0.037037037037037035, 'nationalism': 0.037037037037037035, 'shaped': 0.07407407407407407, 'politics': 0.037037037037037035, 'religion': 0.037037037037037035, 'caste': 0.037037037037037035, 'look': 0.07407407407407407, 'first': 0.2222222222222222, 'evolution': 0.037037 ...

# %%
#The sentence score will go up if the no. of frequent words in the sentence is the more
         
sent_score = {}
sent_index = {}
count=0

for sentence in cleaned_sentences:
  sent_index[sentence] = count
  for word in sentence.split():
    if word in word_weights.keys():
      if sentence not in sent_score.keys():
        sent_score[sentence]=word_weights[word]
      else:
        sent_score[sentence]+=word_weights[word]
  count = count+1
#can be improved by removing wordy sentences

print(sent_score)
# Out:
# {'cricket grew out of the many stick-and-ball games played in england 500 years ago under a variety of different rules ': 2.1111111111111103, 'the word bat is an old english word that simply means stick or club ': 0.8518518518518519, 'by the seventeenth century cricket had evolved enough to be recognisable as a distinct game and it was popular enough for its fans to be fined for playing it on sunday instead of going to church ': 2.370370370370371, 'till the middle of the eighteenth century bats were roughly the same shape as hockey sticks curving outwards at the bottom ': 0.8888888888888886, 'there was a simple reason for this the ball was bowled underarm along the ground and the curve at the end of the bat gave the batsman the best chance of making contact ': 1.7037037037037033, 'how that early version of cricket played in village england grew into the modern game played in giant stadiums in great cities is a proper subject for history because one of the uses of history is to understand how the present was made ': 4.481481481481482, 'and sport is a large part of contemporary life it is one way in which we amuse ourselves compete with each other stay fit and express our social loyalties ': 1.2222222222222219, 'if tens of millions of indians today drop everything to watch the indian team play a test match or a one-day international it is reasonable for a history of india to explore how that stick-and-ball game invented in south-eastern england became the ruling passion of the indian sub-continent ': 2.925925925925926, 'this is particularly so since the game was linked to the wider history of colonialism and nationalism and was in part shaped by the politics of religion and caste ': 1.37037037037037, 'our history of cricket will look first at the evolution of cricket as a game in england and discuss the wider culture of physical training and athleticism of the time ': 4.0, 'it will then move to india discuss the history of the adoption of cricket in this country and trace the modern transformation of the game ': 2.518518518518518, 'in each of these sections we will see how the history of the game was connected to the social history of the time ': 1.7777777777777777, 'the social and economic history of england in the eighteenth and nineteenth centuries crickets early years shaped the game and gave cricket its unique nature ': 3.185185185185185, 'for example one of the peculiarities of test cricket is that a match can go on for five days and still end in a draw ': 1.9259259259259258, 'no other modern team sport takes even half as much time to complete ': 1.4074074074074072, 'a football match is generally over in an hour-and-a-half of playing time ': 0.8518518518518519, 'even baseball a long-drawn-out bat-and-ball game by the standards of modern sport completes nine innings in less than half the time that it takes to play a limited-overs match the shortened version of modern cricket ': 3.740740740740741, 'another curious characteristic of cricket is that the length of the pitch is specified 22 yards but the size or shape of the ground is not ': 2.2222222222222223, 'most other team sports such as hockey and football lay down the dimensions of the playing area cricket does not ': 1.8148148148148149, 'grounds can be oval like the adelaide oval or nearly circular like chepauk in chennai ': 0.7407407407407407, 'a six at the melbourne cricket ground needs to clear much more ground than a lofted shot for the same reward at feroz shah kotla in delhi ': 2.074074074074074, 'theres a historical reason behind both these oddities ': 0.2222222222222222, 'cricket was the earliest modern team sport to be codified which is another way of saying that cricket gave itself rules and regulations so that it could be played in a uniform and standardised way well before team games like soccer and hockey ': 4.666666666666667, 'the first written laws of cricket were drawn up in 1744 ': 1.5555555555555554, 'they stated the principals shall choose from amongst ...

# %%
best_sentences = heapq.nlargest(summ_length,sent_score,key=sent_score.get)
summary_indices=[]
summary=''

for sentence in best_sentences:
  summary_indices.append(sent_index[sentence])
summary_indices.sort() #to maintain coherency

for index in range(0,len(original_sentences)):
  if index in summary_indices:
    summary = summary + original_sentences[index] +'\n'
    
print("***SUMMARY***\n\n"+summary)
# Out:
# ***SUMMARY***
#
# By the seventeenth century, cricket had evolved enough to be recognisable as a distinct game and it was popular enough for its fans to be fined for playing it on Sunday instead of going to church.
# How that early version of cricket played in village England grew into the modern game played in giant stadiums in great cities is a proper subject for history because one of the uses of history is to understand how the present was made.
# If tens of millions of Indians today drop everything to watch the Indian team play a Test match or a one-day international, it is reasonable for a history of India to explore how that stick-and-ball game invented in south-eastern England became the ruling passion of the Indian sub-continent.
# Our history of cricket will look first at the evolution of cricket as a game in England, and discuss the wider culture of physical training and athleticism of the time.
# It will then move to India, discuss the history of the adoption of cricket in this country, and trace the modern transformation of the game.
# The social and economic history of England in the eighteenth and nineteenth centuries, crickets early years, shaped the game and gave cricket its unique nature.
# Even baseball, a long-drawn-out bat-and-ball game by the standards of modern sport, completes nine innings in less than half the time that it takes to play a limited-overs match, the shortened version of modern cricket!
# Another curious characteristic of cricket is that the length of the pitch is specified  22 yards  but the size or shape of the ground is not.
# Cricket was the earliest modern team sport to be codified, which is another way of saying that cricket gave itself rules and regulations so that it could be played in a uniform and standardised way well before team games like soccer and hockey.
# The worlds first cricket club was formed in Hambledon in the 1760s and the Marylebone Cricket Club (MCC) was founded in 1787.
# By 1780, three days had become the length of a major match, and this year also saw the creation of the first six-seam cricket ball.
# While many important changes occurred during the nineteenth century (the rule about wide balls was applied, the exact circumference of the ball was specified, protective equipment like pads and gloves became available, boundaries were introduced where previously all shots had to be run and, most importantly, overarm bowling became legal) cricket remained a pre-industrial sport that matured during the early phase of the Industrial Revolution, the late eighteenth century.
# This history has made cricket a game with characteristics of both the past and the present day.
# Modern factory work meant that people were paid by the hour or the day or the week: games that were codified after the industrial revolution, like football and hockey, were strictly time-limited to fit the routines of industrial city life.
# In the same way, crickets vagueness about the size of a cricket ground is a result of its village origins.
# If you look at the games equipment, you can see how cricket both changed with changing times and yet fundamentally remained true to its origins in rural England.
# The invention of vulcanised rubber led to the introduction of pads in 1848 and protective gloves soon afterwards, and the modern game would be unimaginable without helmets made out of metal and synthetic lightweight materials.

# %%
#writing the summary into a text file
from google.colab import files

filename = "SR_WF_Summary.txt"

with open(filename,"w") as f:
  f.write(summary)

files.download(filename)
